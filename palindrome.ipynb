# %% [markdown]
# <a href="https://colab.research.google.com/github/gutha096/python-lab/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Write a Python program that takes a number as input, checks if it is a palindrome, and then counts and displays the number of occurrences of each digit (0 through 9) in the number."""

input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")

for ch in set(input_str):
    count = input_str.count(ch)
    print(f"'{ch}' appears {count} times")
# Out:
# Enter a string: 1
# Palindrome
# '1' appears 1 times
